# %%
# Função 'print()', usado para imprimir menssagens no console

# %%
print("Olá, eustou a programar em Python")
print("Em: ", 2026)
# Out:
# Olá, eustou a programar em Python
# Em:  2026

# %%
# Exibir uma operação matemática com 'print'

# %%
print(10 + 10)
# Out:
# 20

# %%
print(10*10)
# Out:
# 100

# %%
#                                                             **NOVO TEMA**

# %%
# Operadores Matemáticos da linguagem Python
# Ao trabalharmos com números não ha necessidade do uso das áspas

# %%
print(5-5) # Operador de subtração '-'
# Out:
# 0

# %%
print(5+5) # Operador de adção '+'
# Out:
# 10

# %%
print(5/3) # Operador de divisão '/'
# Out:
# 1.6666666666666667

# %%
print(5*5) # Operador de multiplicação '*'
# Out:
# 25

# %%
print(5//3) # Operação p/ extrair a parte inteira '//'
# Out:
# 1

# %%
print(5**2) # Operação de potência '**'
# Out:
# 25

# %%
print(5%3) # Operação p/ extrair o resto da divisão '%'
# Out:
# 2
