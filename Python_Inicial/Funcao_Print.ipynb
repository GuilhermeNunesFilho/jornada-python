# %%
# função print, usado para imprimir uma mensagem no console

# %%
print("Olá, estou a programar em Python")
# Out:
# Olá, estou a programar em Python

# %%
# Números não precisa está entre aspas

# %%
print(10)
# Out:
# 10

# %%
# Palavreas e números no mesmo print

# %%
print("Guilherme", 1025)
# Out:
# Guilherme 1025
