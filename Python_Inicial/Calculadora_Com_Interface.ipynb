# %%
# 1. Importar as Bibliotecas

# %%
# 2. Criar funções 'limpar e calcular'

# %%
# 3. Criar a janela de interface da calculadora

# %%
# Criar o campo de entradas e saída dos resutados

# %%
# Lista com os rótulos com cada botão, número e operadores

# %%
# Loop que cria e posiciona cada botão

# %%
# 1. Importar as Bibliotecas

import tkinter as tk # Biblioteca para criar interfaces
