# %%
# A função 'inpult' é para entrada de dados, digitada pelo usuário

# %%
input("Digite seu nome: ")
# Out:
# Digite seu nome:  Gabriel
# 'Gabriel'

# %%
# Atribuindo o input a uma variável
nome = input("Digite seu nome: ")
# Out:
# Digite seu nome:  Gabriel

# %%
# Chamando a variável nome
print(nome)
# Out:
# Gabriel

# %%
# Por padrao o input() vem no tipo str, podemos converter o tipo de dados(int,float...), usando essa estrutura
idade = int(input("Digite sua idade:\n")) # O '\n' usado ao final da frase serve para da uma quebra de linha(usado a conviniência)
# Out:
# Digite sua idade:
#  15

# %%
altura = float(input("Qual é a sua altura: ")) # Lembrando que números decimais são separados por ponto
# Out:
# Qual é a sua altura:  1.96

# %%
print(altura)
# Out:
# 1.96
