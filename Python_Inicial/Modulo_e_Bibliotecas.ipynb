# %%
# Um Módulo é um pacote de funções que existem dentro de uma biblioteca

# %%
# Importando um módulo de matemática para fazer a mesma calculadara de fatorial do tópico 'While'
import math # esse módulo trabalha com operações matemática
math.factorial(5) # essa função realiza a maesma coisa que a calculadora feita com while
# Out:
# 120

# %%
import math
numero = int(input("Digite um número p/ fatoriar: "))
res = math.factorial(numero)
print(f"O {numero} tem seu fatorial de : {res}")
# Out:
# Digite um número p/ fatoriar:  6
# O 6 tem seu fatorial de : 720
