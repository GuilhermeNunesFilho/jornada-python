# %%
# Format, usado para mesclar mensagens em prints com variáveis pronta

# %%
# Vamos criar umas variáveis de carro para usarmos no exemplo

# %%
carro1 = "celta"
carro2 = "gol"
carro3 = "Astra"

# %%
# Mesclando com Format. e seus tipo de estrutura

# %%
# tipo 1
print(
    "Ness fim de semana, fomos viajar. No entando meu {} acabou quebrando no meio do caminho".format(carro1)
) # você pode usar o mesmo print para escrever em várias linha desde que use a sintaxe correta!
# Out:
# Ness fim de semana, fomos viajar. No entando meu celta acabou quebrando no meio do caminho

# %%
# tipo 2
print(f"Comprei um {carro2}") # Esse jeito é mais prático
# Out:
# Comprei um gol
