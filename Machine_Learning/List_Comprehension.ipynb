# %%
# Mais formas diferente de ultilizar as ferramentas
num = [1,2,3,4,5,6,7]

# %%
num_Mult_3 = [i * 3 for i in num]
print(num_Mult_3)
# Out:
# [3, 6, 9, 12, 15, 18, 21]

# %%
_EuSou = [i for i in "Amo programação"]
print(_EuSou)
# Out:
# ['A', 'm', 'o', ' ', 'p', 'r', 'o', 'g', 'r', 'a', 'm', 'a', 'ç', 'ã', 'o']
