# %%
# Existe vários jeito e comandos diferentes para manipular uma string

# %%
apresentacao = "Olá, meu nome é Guilherme e estudo Programação a 1 ano."
print(apresentacao)
# Out:
# Olá, meu nome é Guilherme e estudo Programação a 1 ano.

# %%
apresentacao[1:6:4]
# Out:
# 'lm'

# %%
apresentacao.replace("meu nome é","me chamo")
# Out:
# 'Olá, me chamo Guilherme e estudo Programação a 1 ano.'

# %%
len(apresentacao)
# Out:
# 55

# %%
for i in apresentacao:
    len(i)
    print(i)
# Out:
# O
# l
# á
# ,
#
# m
# e
# u
#
# n
# o
# m
# e
#
# é
#
# G
# u
# i
# l
# h
# e
# r
# m
# e
#
# e
#
# e
# s
# t
# u
# d
# o
#
# P
# r
# o
# g
# r
# a
# m
# a
# ç
# ã
# o
#
# a
#
# 1
#
# a
# n
# o
# .

# %%
# Essas são algumas, de inumeras manipulações
