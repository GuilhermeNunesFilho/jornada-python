# %%
# !pip install pandas openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
import pandas as pd

# %%
tabela = pd.read_excel("C:/Users/Guilherme/Desktop/Estudos/Python/Pandas/Tabela_de_Notas.xlsx") # Buscando o arquivo

# %%
tabela.head(8) # Imprimido o arquivo buscado Excel
# Out:
#               Nome  1° Semestre  2° Semestre  Nota Final
# 0      Juão Carlos            5            8         6.5
# 1  Maria de Lurdes            8            7         7.5
# 2  Guilherme Nunes            9            6         7.5
# 3       José Alvez           10            5         7.5
# 4      Alex Soárez            4            8         6.0
# 5     Luanna Gomez            6            7         6.5
# 6       Vera Lucia            8            5         6.5
# 7     Thiago Lopez            7            4         5.5
