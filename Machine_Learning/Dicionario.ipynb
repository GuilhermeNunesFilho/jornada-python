# %%
# Dicionários armazenas produto e valor e são utilizadas chaves {}

# %%
dicionario = {
    "Arroz":"R$:0,16",
    "Feijão":"R$:0,56",
    "Açucar":"R$:0,06",
    "Café":"R$:0,08"
}

# %%
print(dicionario)
# Out:
# {'Arroz': 'R$:0,16', 'Feijão': 'R$:0,56', 'Açucar': 'R$:0,06', 'Café': 'R$:0,08'}

# %%
print(dicionario["Arroz"])
# Out:
# R$:0,16

# %%
print(dicionario.values())
# Out:
# dict_values(['R$:0,16', 'R$:0,56', 'R$:0,06', 'R$:0,08'])

# %%
print(dicionario.keys())
# Out:
# dict_keys(['Arroz', 'Feijão', 'Açucar', 'Café'])
