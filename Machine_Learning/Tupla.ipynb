# %%
# Diferente de listas as tuplas são imutáveis e utilizamos parentes() ao invés de colchetes[]

# %%
lista1 = [1,2,3]
print(lista1)
# Out:
# [1, 2, 3]

# %%
lista1.append(10)

# %%
print(lista1)
# Out:
# [1, 2, 3, 10]

# %%
# tuplas

tupla = (1,2,3,4)

# %%
print(tupla)
# Out:
# (1, 2, 3, 4)

# %%
tupla.append(25) # lembrete: tuplas imutavel
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 tupla.append(25)
#
# AttributeError: 'tuple' object has no attribute 'append'
