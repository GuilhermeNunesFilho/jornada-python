# %%
# Criando e visualizando uma tabela
import pandas as pd

# %%
notas = {
    "Alunos": ["Maria Claudia","Lucas José","Carlos Augusto","Jonas Lopez","Suzi Naki"],
    "Notas": [10,8,7,4,3],
    "Situação": ["Aprovado","Aprovado","Aprovado","Reprovado","Reprovado"]
}

# %%
tabela = pd.DataFrame(notas)

# %%
print(tabela)
# Out:
#            Alunos  Notas   Situação
# 0   Maria Claudia     10   Aprovado
# 1      Lucas José      8   Aprovado
# 2  Carlos Augusto      7   Aprovado
# 3     Jonas Lopez      4  Reprovado
# 4       Suzi Naki      3  Reprovado
