# %%
# Importando Biblioteca pyautogui
import pyautogui

# %%
# Mostrando a posição do mouse

posicao = pyautogui.position()
print(f"A posição do seu mouse é: {posicao}")

# Mostrando o tamanho da Tela

tamanho = pyautogui.size()
print(f"O tamanho da tela é: {tamanho}")
# Out:
# A posição do seu mouse é: Point(x=650, y=538)
# O tamanho da tela é: Size(width=1600, height=900)
