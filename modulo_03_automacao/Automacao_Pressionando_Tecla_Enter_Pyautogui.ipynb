# %%
# Pressionando uma tecla

# %%
import pyautogui
import time

# %%
time.sleep(5)

# escrevendo texto automatizado com intervalo de digitação de 0.2
pyautogui.write("www.github.com", interval= 0.2)
time.sleep(1)

pyautogui.press("enter")
