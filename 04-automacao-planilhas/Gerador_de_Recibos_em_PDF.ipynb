# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeNunesFilho/jornada-python/blob/main/04-automacao-planilhas/Gerador_de_Recibos_em_PDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Gerador de Recibos/Certificados em PDF
lista_vendedor = [
    ["Ana", "Caixa de Som", 2500],
    ["Pedro", "Celular", 1800],
    ["Lucas", "Geladeira", 3000]
]
vendedor = 0
for lista in lista_vendedor:
  vendedor = lista
  pdf = canvas.Canvas(f"recibo_{vendedor[0]}.pdf")

  pdf.drawString(100, 750, f"Recibo de Comissão - {vendedor[0]}")
  pdf.drawString(100, 730, f"Produto vendido: {vendedor[1]}")
  pdf.drawString(100, 710, f"Valor: R$ {vendedor[2]}")
  canvas.Canvas(f"recibo_{vendedor[0]}.pdf")

  comissao = vendedor[2] * 0.1
  pdf.drawString(100, 690, f"Comissão a receber: R$ {comissao}")

  pdf.save()
